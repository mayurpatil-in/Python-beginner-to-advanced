# %%
print("Hello")
# Out:
# Hello

# %%
class car:
    pass

# %%
car
# Out:
# __main__.car

# %%
class student:
    def __init__(self,name,rollNo,marks):
        self.name = name
        self.rollNo = rollNo
        self.marks = marks
    def study(self):
        print("My name is " + self.name)

# %%
s1 = student("Mayur",2,90)

# %%
s2 = student("goku",3,99)

# %%
s1.name, s1.rollNo, s1.marks
# Out:
# ('Mayur', 2, 90)

# %%
s1.study()
# Out:
# My name is Mayur
